# %% [markdown]
# # Zomato Restaurants Project

# %% [markdown]
# ## Project Description

# %% [markdown]
# Zomato Data Analysis is one of the most useful analysis for foodies who want to taste the best
# cuisines of every part of the world which lies in their budget. This analysis is also for those who
# want to find the value for money restaurants in various parts of the country for the cuisines.
# Additionally, this analysis caters the needs of people who are striving to get the best cuisine of
# the country and which locality of that country serves that cuisines with maximum number of
# restaurants.
#
# Data Storage:
#
# This problem statement contains two datasets- Zomato.csv and country_code.csv.
# Country_code.csv contains two variables:
#
# • Country code
#
# • Country name
#
# The collected data has been stored in the Comma Separated Value file Zomato.csv. Each
# restaurant in the dataset is uniquely identified by its Restaurant Id. Every Restaurant contains the following variables:
#
# • Restaurant Id: Unique id of every restaurant across various cities of the world
#
# • Restaurant Name: Name of the restaurant
#
# • Country Code: Country in which restaurant is located
#
# • City: City in which restaurant is located
#
# • Address: Address of the restaurant
#
# • Locality: Location in the city
#
#
# • Locality Verbose: Detailed description of the locality
#
# • Longitude: Longitude coordinate of the restaurant&#39;s location
#
# • Latitude: Latitude coordinate of the restaurant&#39;s location
#
# • Cuisines: Cuisines offered by the restaurant
#
# • Average Cost for two: Cost for two people in different currencies ��
#
# • Currency: Currency of the country
#
# • Has Table booking: yes/no
#
# • Has Online delivery: yes/ no
#
# • Is delivering: yes/ no
#
# • Switch to order menu: yes/no
#
# • Price range: range of price of food
#
# • Aggregate Rating: Average rating out of 5
#
# • Rating color: depending upon the average rating color
#
# • Rating text: text on the basis of rating of rating
#
# • Votes: Number of ratings casted by people
#
# ***Problem statement : In this dataset predict 2 things –***
#
# 1) Average Cost for two
#
# 2) Price range

# %%
import numpy as np
import pandas as pd 
import seaborn as sb
import matplotlib.pyplot as pt
import warnings
warnings.filterwarnings('ignore')

# %%
df1=pd.read_csv(r'https://raw.githubusercontent.com/dsrscientist/dataset4/main/zomato.csv',encoding="ISO-8859-1")
df1
# Out:
#       Restaurant ID           Restaurant Name  Country Code              City  \
# 0           6317637          Le Petit Souffle           162       Makati City
# 1           6304287          Izakaya Kikufuji           162       Makati City
# 2           6300002    Heat - Edsa Shangri-La           162  Mandaluyong City
# 3           6318506                      Ooma           162  Mandaluyong City
# 4           6314302               Sambo Kojin           162  Mandaluyong City
# ...             ...                       ...           ...               ...
# 9546        5915730              NamlÛ± Gurme           208         ÛÁstanbul
# 9547        5908749             Ceviz AÛôacÛ±           208         ÛÁstanbul
# 9548        5915807                     Huqqa           208         ÛÁstanbul
# 9549        5916112              Aôôk Kahve           208         ÛÁstanbul
# 9550        5927402  Walter's Coffee Roastery           208         ÛÁstanbul
#
# ...

# %% [markdown]
# This is our first dataset which contains all the information regarding every restaurant.Also we used encoding because without it, there was 'utf-8 codec' error.

# %%
df2=pd.read_excel(r'C:\Nimish\Country-code.xlsx')
df2
# Out:
#     Country Code         Country
# 0              1           India
# 1             14       Australia
# 2             30          Brazil
# 3             37          Canada
# 4             94       Indonesia
# 5            148     New Zealand
# 6            162     Phillipines
# 7            166           Qatar
# 8            184       Singapore
# 9            189    South Africa
# 10           191       Sri Lanka
# 11           208          Turkey
# 12           214             UAE
# 13           215  United Kingdom
# 14           216   United States

# %% [markdown]
# This DataFrame contains Countries and their correspoding codes. We will merge both of these columns to have a better view of the data.

# %%
df=pd.merge(df1,df2)
df
# Out:
#       Restaurant ID           Restaurant Name  Country Code              City  \
# 0           6317637          Le Petit Souffle           162       Makati City
# 1           6304287          Izakaya Kikufuji           162       Makati City
# 2           6300002    Heat - Edsa Shangri-La           162  Mandaluyong City
# 3           6318506                      Ooma           162  Mandaluyong City
# 4           6314302               Sambo Kojin           162  Mandaluyong City
# ...             ...                       ...           ...               ...
# 9546        5915730              NamlÛ± Gurme           208         ÛÁstanbul
# 9547        5908749             Ceviz AÛôacÛ±           208         ÛÁstanbul
# 9548        5915807                     Huqqa           208         ÛÁstanbul
# 9549        5916112              Aôôk Kahve           208         ÛÁstanbul
# 9550        5927402  Walter's Coffee Roastery           208         ÛÁstanbul
#
# ...

# %% [markdown]
# We can see that both the dataframes are now merged and countries have been assigned to each row according to the country code.
# There are total of 9551 rows and 22 columns from which **price range** and **avg cost for two** will be our target columns one after the another. By looking a the data we can have an idea that price range may be a **classification problem** as it looks like it has discrete values for a particular scale and avg price for two will be  a **regression problem**.

# %% [markdown]
# ## Explanatory Data Analysis

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 9551 entries, 0 to 9550
# Data columns (total 22 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Restaurant ID         9551 non-null   int64
#  1   Restaurant Name       9551 non-null   object
#  2   Country Code          9551 non-null   int64
#  3   City                  9551 non-null   object
#  4   Address               9551 non-null   object
#  5   Locality              9551 non-null   object
#  6   Locality Verbose      9551 non-null   object
#  7   Longitude             9551 non-null   float64
#  8   Latitude              9551 non-null   float64
#  9   Cuisines              9542 non-null   object
#  10  Average Cost for two  9551 non-null   int64
#  11  Currency              9551 non-null   object
#  12  Has Table booking     9551 non-null   object
#  13  Has Online delivery   9551 non-null   object
#  14  Is delivering now     9551 non-null   object
# ...

# %% [markdown]
# From above information we see that there are no null values present except in the cuisine column which is very less so we will remove the null values and as we see that data is a mix of object and float datatypes, which we will seperate accordingly.

# %%
df.dropna(inplace=True)

# %%
int_cols=[]
for i in  df.dtypes.index:
    if df.dtypes[i]!=object:
        int_cols.append(i)
        
obj_cols=[]
for i in df.dtypes.index:
    if df.dtypes[i]==object :
        obj_cols.append(i)

print('float columns are=',int_cols,'\n')
print('Object columns are=',obj_cols)
# Out:
# float columns are= ['Restaurant ID', 'Country Code', 'Longitude', 'Latitude', 'Average Cost for two', 'Price range', 'Aggregate rating', 'Votes']
#
# Object columns are= ['Restaurant Name', 'City', 'Address', 'Locality', 'Locality Verbose', 'Cuisines', 'Currency', 'Has Table booking', 'Has Online delivery', 'Is delivering now', 'Switch to order menu', 'Rating color', 'Rating text', 'Country']

# %% [markdown]
# We have seperated the columns, now we will check for unique values present in the object type columns.
# We will also check for duplicated values and if present we will remove them

# %%
for i in obj_cols:
    print ("\033[1m"+i+"\033[0m")
    print(df[i].value_counts())
    print('*'*75)
# Out:
# Restaurant Name
# Cafe Coffee Day             83
# Domino's Pizza              79
# Subway                      63
# Green Chick Chop            51
# McDonald's                  48
#                             ..
# The Town House Cafe          1
# The G.T. Road                1
# The Darzi Bar & Kitchen      1
# Smoke On Water               1
# Walter's Coffee Roastery     1
# Name: Restaurant Name, Length: 7437, dtype: int64
# ***************************************************************************
# City
# New Delhi    5473
# Gurgaon      1118
# Noida        1080
# Faridabad     251
# Ghaziabad      25
#              ...
# Panchkula       1
# Huskisson       1
# Forrest         1
# Flaxton         1
# Consort         1
# Name: City, Length: 140, dtype: int64
# ***************************************************************************
# Address
# Dilli Haat, INA, New Delhi                                                   11
# ...

# %% [markdown]
# From above we notice that the ***restaurant name*** and ***address*** have too many unique values so that wont be contributing much in our prediction. Also stated in our problem statement it is the locality and cuisine which is a matter of interest.
#
# And, ***locality*** and ***locality verbose*** columns provide almost the same data with verbose providing some extra irrelevant data as the word verbose describes. So we will dropping the verbose column.Locality column also contains the city's name so ***city*** column is also not needed.
#
# And, ***longitude and latitude*** columns are not much needed in our dataset as we already have the locality column.
#
# Also as the country code and country would be same after encoding the data, so ***country code*** wont be useful as much and
# just provide multicollinearity.
#
# And, ***switch to order menu*** column has only one value and ***is delivering now*** column also have almost one unique value so that wont be affecting our prediction.
#
# And, ***rating text*** and ***rating color*** are similar toeach ther with equal valuesso those will just provide multicollinearity after ecnoding so we can drop one out of the two.
#
# So we will be ***dropping ten columns.***

# %%
df.drop(columns=['Switch to order menu','Restaurant Name','Address','Locality Verbose','Is delivering now','Switch to order menu','Rating color','Longitude','Latitude','Country Code','City'],inplace=True)

# %%
df.describe()
# Out:
#        Restaurant ID  Average Cost for two  Price range  Aggregate rating  \
# count   9.542000e+03           9542.000000  9542.000000       9542.000000
# mean    9.043301e+06           1200.326137     1.804968          2.665238
# std     8.791967e+06          16128.743876     0.905563          1.516588
# min     5.300000e+01              0.000000     1.000000          0.000000
# 25%     3.019312e+05            250.000000     1.000000          2.500000
# 50%     6.002726e+06            400.000000     2.000000          3.200000
# 75%     1.835260e+07            700.000000     2.000000          3.700000
# max     1.850065e+07         800000.000000     4.000000          4.900000
#
#               Votes
# count   9542.000000
# mean     156.772060
# std      430.203324
# min        0.000000
# 25%        5.000000
# 50%       31.000000
# 75%      130.000000
# max    10934.000000

# %% [markdown]
# From the above details we can notice the following-
#
# 1. Range,Mean and Standard deviation of each column
# 2. There maybe some outliers present as 75 % values and max vaues have considerable differences in some columns.
# 3. Skewness present in some columns as mean and median (50%) values are different for some columns.
#
# Also Restaurant id is also an irrelevant column in our prediction so we will dropping it as well.

# %%
df.drop(['Restaurant ID'],axis=1,inplace=True)

# %%
df.describe(include=object)
# Out:
#                Locality      Cuisines            Currency Has Table booking  \
# count              9542          9542                9542              9542
# unique             1206          1825                  12                 2
# top     Connaught Place  North Indian  Indian Rupees(Rs.)                No
# freq                122           936                8652              8384
#
#        Has Online delivery Rating text Country
# count                 9542        9542    9542
# unique                   2           6      15
# top                     No     Average   India
# freq                  7091        3734    8652

# %% [markdown]
# From above desribe function we are describing the data from all the object type columns and we notice the following-
#
# 1. Unique values in each columns
# 2. Most frequent value in each column. (mode)
# 3. Frequency of the most occuring value.

# %%
int_cols=[]
for i in  df.dtypes.index:
    if df.dtypes[i]!=object:
        int_cols.append(i)
        
obj_cols=[]
for i in df.dtypes.index:
    if df.dtypes[i]==object :
        obj_cols.append(i)

# %% [markdown]
# Updating the lists with new data after removing the columns.

# %% [markdown]
# ## Visualisation

# %% [markdown]
# #### Count Plots

# %%
pt.figure(figsize=(30,30))
sb.set(font_scale=2)
p=1
q=1
for i in obj_cols[3:]:
    if p<=5:
        ax=pt.subplot(3,2,p)
        sb.countplot(x=df[i],palette='CMRmap')
        pt.xticks(rotation=90)
        p+=1
pt.tight_layout()

# %% [markdown]
# From above graphs we notice the following-
# 1. India and indian currency(rupees) is present the most in our dataset.
# 2. Most of the restaurants dont provide table booking.
# 3. Only few restaurants provide online delivery
# 4. Most ratings are in the categories- good/ average/ not rated.

# %% [markdown]
# #### Regression plots

# %%
int_cols
# Out:
# ['Average Cost for two', 'Price range', 'Aggregate rating', 'Votes']

# %%
p=1
pt.figure(figsize=(15,6))
sb.set(font_scale=1)
for i in int_cols[1:]:
    if p<=3:
        ax=pt.subplot(1,3,p)
        sb.regplot(x='Average Cost for two',y=df[i],scatter_kws=dict(color='r'),line_kws=dict(color='k'),data=df)
        pt.xticks(rotation=90)
        p+=1
pt.tight_layout()

# %% [markdown]
# We have plotted regression plots to find the relation between the Average cost for two and other numerical variables and we notice that it has direct relation with all of them.

# %%
sb.set(font_scale=1.4)
sb.set_style('whitegrid')
fig,axes = pt.subplots(2, 2, figsize=(24,15))
fig.suptitle('Price range according to different Parameters',fontsize=30) 
sb.countplot(ax=axes[0, 0],x='Has Online delivery',hue='Price range',data=df,palette="Set2") 
sb.ecdfplot(ax=axes[0, 1],x='Aggregate rating',hue='Price range', data=df,palette="Dark2",stat='count')
sb.histplot(ax=axes[1, 0],x='Rating text',hue='Price range',data=df,palette="gnuplot",multiple='stack')
sb.boxplot(ax=axes[1, 1],x='Country',y='Price range',data=df,palette="spring")
pt.xticks(rotation=90)
pt.show()

# %% [markdown]
# From above graphs we have the following observations-
#
# 1. Restaurants with price range of 2-3 are the ones which provide home delivery the most in proportion to their total count.
# 2. a) Price range of 1 - 2 restaurants are present the most till 2.5 aggregrate ratings, with sharp rise after 2.5 aggregrate ratings
#    b) Price range with 3-4 restaurants are almost negligible till 2.5 and very few till 3 aggregrate ratings but there is rise       after 3-3.5 ag=ffrefrate ratings
# 3. Restaurants with price ranged 1 are mostly rated as Average and not rated, restaurants with 2 price range are mostly considered Average-Good , while restaurants with 3-4 price range lies between Good to Excellent range.
# 4. 4th graph shows us how the price range varies with each country. With Phillipines, Brazil, Sinagpore, UAE, Qatar, New Zealand and South Africa have most( acc to IQR) of their restaurants in the price range 3-4 making them the most expensive, India is the one with most(acc to IQR) of their restaurants in the price range 1-2.

# %% [markdown]
# ## Encoding

# %% [markdown]
# As our target variable is in numerical format only so we will not encode the Price range column but we will encode the other categorical columns using the ordinal encoder.

# %%
from sklearn.preprocessing import OrdinalEncoder
oe=OrdinalEncoder()

# %%
for i in obj_cols:
    df[i]=oe.fit_transform(df[i].values.reshape(-1,1))

# %%
df
# Out:
#       Locality  Cuisines  Average Cost for two  Currency  Has Table booking  \
# 0        171.0     920.0                  1100       0.0                1.0
# 1        592.0    1111.0                  1200       0.0                1.0
# 2        308.0    1671.0                  4000       0.0                1.0
# 3        860.0    1126.0                  1500       0.0                0.0
# 4        860.0    1122.0                  1500       0.0                1.0
# ...        ...       ...                   ...       ...                ...
# 9546     516.0    1813.0                    80      11.0                0.0
# 9547     551.0    1824.0                   105      11.0                0.0
# 9548     553.0    1110.0                   170      11.0                0.0
# 9549     553.0    1657.0                   120      11.0                0.0
# 9550     668.0     331.0                    55      11.0                0.0
#
# ...

# %% [markdown]
# ## Multivariate analysis

# %% [markdown]
# ### Heatmap to find the correlation

# %%
pt.figure(figsize=(8,5))
sb.set(font_scale=1)
sb.heatmap(df.corr(),mask=np.triu(df.corr()),cmap='turbo',annot=True,fmt='.2f',vmin=-0.5,vmax=0.5)
# Out:
# <Axes: >

# %% [markdown]
# ### Pairplot

# %%
sb.pairplot(df)

# %% [markdown]
# ## Using boxplot and zscore to check and remove outliers

# %%
pt.figure(figsize=(10,3))
sb.set(font_scale=0.7)
p=1
for i in int_cols:
    if p<=4:
        ax=pt.subplot(1,4,p)
        sb.boxplot(df[i],color='cyan')
        pt.xlabel(i,fontsize=10)
    p+=1
pt.tight_layout()

# %%
from scipy.stats import zscore
z=np.abs(zscore(df))
thershold=3
df1=df[(z<3).all(axis = 1)]
print ("Shape of the dataframe before removing outliers: ", df.shape)
print ("Shape of the dataframe after removing outliers: ", df1.shape)
print ("Percentage of data loss post outlier removal: ", (df.shape[0]-df1.shape[0])/df.shape[0]*100)
# Out:
# Shape of the dataframe before removing outliers:  (9542, 11)
# Shape of the dataframe after removing outliers:  (8590, 11)
# Percentage of data loss post outlier removal:  9.976944036889542

# %% [markdown]
# SO the data loss is 9.9% which is below the acceptable range of 10%, so we will be removing the outliers.

# %% [markdown]
# ## Now checking and removing skewness using distplot and log transformation

# %%
pt.figure(figsize=(22,20))
p=1
for i in int_cols:
    if p<=16:
        ax=pt.subplot(4,4,p)
        sb.distplot(df1[i],  color="lightskyblue", kde_kws={"shade": True},hist=False)
        pt.xlabel(i,fontsize=15)
    p+=1
pt.show()
df1.skew()
# Out:
# Locality               -0.309375
# Cuisines               -0.345319
# Average Cost for two    3.694009
# Currency               -0.870838
# Has Table booking       2.305305
# Has Online delivery     1.004879
# Price range             1.026645
# Aggregate rating       -0.881131
# Rating text             0.431043
# Votes                   3.665666
# Country                 7.601446
# dtype: float64

# %% [markdown]
# As we only remove skewness from the numerical AND float datatype columns so we will be treating Average cost for two and votes column only.

# %%
df2=df1.copy() #so that df1 dataframe doesnt have any changes when we take averge cost for two as target variable
df2['Average Cost for two']=np.log1p(df2['Average Cost for two'])
df2['Votes']=np.log1p(df2['Votes'])

# %% [markdown]
# We have removed the skewness , now we will scale the data using standard scaler

# %% [markdown]
# ## Standard Scaling

# %%
from sklearn.preprocessing import StandardScaler
sc=StandardScaler()

# %%
#splitting the dataset for predicting Price range first
x=df2.drop(['Price range'],axis=1)
y=df2['Price range']

# %%
x=pd.DataFrame(sc.fit_transform(x),columns=x.columns)
x.head()
# Out:
#    Locality  Cuisines  Average Cost for two  Currency  Has Table booking  \
# 0 -1.990519 -1.563061             -3.867618 -9.871178          -0.373374
# 1 -1.898821  0.517518             -3.867618 -9.871178          -0.373374
# 2 -1.839872  1.210383             -3.867618 -9.871178          -0.373374
# 3 -1.279859 -0.772917             -5.088781 -9.871178          -0.373374
# 4 -1.214361 -1.346665             -3.867618 -9.871178          -0.373374
#
#    Has Online delivery  Aggregate rating  Rating text     Votes   Country
# 0            -0.616736          0.657407     0.219946  0.097334 -9.417521
# 1            -0.616736          0.458403    -1.017746  0.010315 -9.417521
# 2            -0.616736          1.387087    -0.398900  1.250696 -9.417521
# 3            -0.616736          0.723742     0.219946  0.171875 -9.417521
# 4            -0.616736          1.055414     2.076485  0.506216 -9.417521

# %% [markdown]
# ## Checking for multicollinearity using VIF values

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor
vif = pd.DataFrame()
vif['Features'] = x.columns
vif['vif'] = [variance_inflation_factor(x,i) for i in range(x.shape[1])]
vif
# Out:
#                Features       vif
# 0              Locality  1.035823
# 1              Cuisines  1.018513
# 2  Average Cost for two  1.645616
# 3              Currency  1.051394
# 4     Has Table booking  1.435016
# 5   Has Online delivery  1.176964
# 6      Aggregate rating  4.718833
# 7           Rating text  1.316816
# 8                 Votes  4.935918
# 9               Country  1.050482

# %% [markdown]
# As all the values are under 10 , hence there is no multicollinearity present in our dataset

# %% [markdown]
# ## Balancing the dataset using SMOTE

# %%
from imblearn.over_sampling import SMOTE
os=SMOTE()
y.value_counts()
# Out:
# 1    4296
# 2    2846
# 3    1056
# 4     392
# Name: Price range, dtype: int64

# %%
x,y=os.fit_resample(x,y)
y.value_counts()
# Out:
# 2    4296
# 1    4296
# 3    4296
# 4    4296
# Name: Price range, dtype: int64

# %% [markdown]
# The data is balanced now

# %% [markdown]
# ## Model building (classification models)

# %%
from sklearn.model_selection import train_test_split,cross_val_score
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import GradientBoostingClassifier

from sklearn.svm import SVC
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report

# %%
models=[GaussianNB(),LogisticRegression(),RandomForestClassifier(),KNeighborsClassifier(),DecisionTreeClassifier(), SVC()]

# %% [markdown]
# ### Finding the best random state

# %%
maxAcc = 0
maxRS = 0

for i in range(1,50):
    x_train,x_test,y_train,y_test = train_test_split(x,y,test_size = .25, random_state=i)
    for m in models:
        m.fit(x_train,y_train)
        m.score(x_train,y_train)
        pred = m.predict(x_test)
        acc = accuracy_score(y_test,pred)
        if acc>maxAcc:
            maxAcc = acc
            maxRs=i
print("Best Accuracy is:", maxAcc, "on Random State:", maxRs)
# Out:
# Best Accuracy is: 0.9897579143389199 on Random State: 35

# %% [markdown]
# So the best random state is 35

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size = .25, random_state=35)

# %% [markdown]
# ## Every model with metrics

# %%
for m in models:
    m.fit(x_train,y_train)
    m.score(x_train,y_train)
    predm=m.predict(x_test)
    print('\033[1m','For' ,m,'\033[0m','Accuracy score is: ',accuracy_score(y_test,predm))
    print ('\n','Confusion matrix:','\n',confusion_matrix(y_test,predm))
    print ('\n','Classification Report:','\n',classification_report(y_test,predm))
    cvs=cross_val_score(m,x,y)
    print('Cross Validation Score=',cvs.mean(),'\n')
    print('*'*80)
# Out:
#  For GaussianNB()  Accuracy score is:  0.5039571694599627
#
#  Confusion matrix:
#  [[1070    0    1    3]
#  [1042    9   72    8]
#  [ 418   27  548   47]
#  [ 310   16  187  538]]
#
#  Classification Report:
#                precision    recall  f1-score   support
#
#            1       0.38      1.00      0.55      1074
#            2       0.17      0.01      0.02      1131
#            3       0.68      0.53      0.59      1040
#            4       0.90      0.51      0.65      1051
#
#     accuracy                           0.50      4296
#    macro avg       0.53      0.51      0.45      4296
# weighted avg       0.52      0.50      0.44      4296
#
# Cross Validation Score= 0.5893279259499868
#
# ********************************************************************************
#  For LogisticRegression()  Accuracy score is:  0.9027001862197392
#
#  Confusion matrix:
#  [[ 974  100    0    0]
#  [   9 1014  108    0]
#  [  13   63  900   64]
#  [   0    6   55  990]]
#
# ...

# %% [markdown]
# So the best working model is Random Forest Classifier , confirmed with cross validation score

# %% [markdown]
# ## Hyperparameter Tuning

# %%
from sklearn.model_selection import GridSearchCV
param = {'max_features':['auto','sqrt','log2'],
      'max_depth':[5,10,15,20,25],
      'criterion':['gini','entropy']}
gcs=GridSearchCV(RandomForestClassifier(),param,cv=5)
gcs.fit(x_train,y_train)
gcs.best_params_
# Out:
# {'criterion': 'entropy', 'max_depth': 20, 'max_features': 'sqrt'}

# %%
fmodel=RandomForestClassifier(max_features='auto',criterion='gini',max_depth=15)
fmodel.fit(x_train,y_train)
pred=fmodel.predict(x_test)
acc=accuracy_score(y_test,pred)
print(acc*100)
# Out:
# 98.76629422718808

# %% [markdown]
# ## Confusion Matrix

# %%
from sklearn.metrics import ConfusionMatrixDisplay
cm = confusion_matrix(y_test, pred)
cm_display = ConfusionMatrixDisplay(cm).plot(cmap='gist_earth')
pt.grid(False)

# %% [markdown]
# ## Saving the model

# %%
import joblib
joblib.dump(fmodel,'Zomato_price-range.obj')
# Out:
# ['Zomato_price-range.obj']

# %% [markdown]
# ## Now bulding models with Average cost for two as target variable

# %% [markdown]
# As we had already removed outliers we will just remove skewness

# %%
df3=df1.copy()
df3['Votes']=np.log1p(df3['Votes'])

# %%
#splitting the dataset
x1=df3.drop(['Average Cost for two'],axis=1)
y1=df3['Average Cost for two']

# %% [markdown]
# ## Scaling using Standard Scaler

# %%
x1=pd.DataFrame(sc.fit_transform(x1),columns=x1.columns)

# %% [markdown]
# ## Checking for multicollinearity using VIF values

# %%
vif1 = pd.DataFrame()
vif1['Features'] = x.columns
vif1['vif'] = [variance_inflation_factor(x1,i) for i in range(x1.shape[1])]
vif1
# Out:
#               Features       vif
# 0             Locality  1.035768
# 1             Cuisines  1.019242
# 2             Currency  1.049988
# 3    Has Table booking  1.498618
# 4  Has Online delivery  1.174838
# 5          Price range  1.906675
# 6     Aggregate rating  4.723304
# 7          Rating text  1.344825
# 8                Votes  4.993803
# 9              Country  1.073470

# %% [markdown]
# As all the values are way below 10, there is no multicollinearity present in our dataset, we will build the models now

# %% [markdown]
# ## Model Building

# %%
from sklearn.linear_model import LinearRegression, Ridge, Lasso
from sklearn.svm import SVR
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.neighbors import KNeighborsRegressor
from sklearn.ensemble import AdaBoostRegressor
from sklearn.ensemble import GradientBoostingRegressor
from xgboost import XGBRegressor
from sklearn.metrics import r2_score,mean_absolute_error,mean_squared_error
from sklearn.model_selection import train_test_split,cross_val_score

# %%
models_reg=[LinearRegression(),Ridge(),Lasso(),SVR(),XGBRegressor(),GradientBoostingRegressor(),RandomForestRegressor(),KNeighborsRegressor(),DecisionTreeRegressor()]

# %% [markdown]
# ### Finding the best random state

# %%
maxAcc = 0
maxRS = 0

for i in range(1,50):
    xtrain,xtest,ytrain,ytest = train_test_split(x1,y1,test_size = .25, random_state=i)
    for m in models_reg:
        m.fit(xtrain,ytrain)
        pred = m.predict(xtest)
        acc = r2_score(ytest,pred)
        if acc>maxAcc:
            maxAcc = acc
            maxRs=i
print("Best Accuracy is:", maxAcc, "on Random State:", maxRs)
# Out:
# Best Accuracy is: 0.878441420196141 on Random State: 49

# %% [markdown]
# So the best random state is 49

# %%
 x_train,x_test,y_train,y_test = train_test_split(x1,y1,test_size = .25, random_state=49)

# %% [markdown]
# ## Each model with metrics

# %%
for m in models_reg:
    m.fit(x_train,y_train)
    mpred=m.predict(x_test)
    print('\033[1m','For',m,'\033[0m')
    print("R2 score :",r2_score(y_test, mpred))
    print("Mean absolute error: ", mean_absolute_error(y_test,mpred))
    print("Mean squared error: ", mean_squared_error(y_test,mpred))
    cvs=cross_val_score(m,x1,y1,cv=5,scoring='r2')
    print('Cross Validation Score=',cvs.mean(),'\n')
    print('*'*75)
# Out:
#  For LinearRegression()
# R2 score : 0.7058686138139211
# Mean absolute error:  168.37179811414038
# Mean squared error:  83752.4039673283
# Cross Validation Score= 0.48574944211236326
#
# ***************************************************************************
#  For Ridge()
# R2 score : 0.7058817955791052
# Mean absolute error:  168.35168979538832
# Mean squared error:  83748.65052728567
# Cross Validation Score= 0.4858680392627509
#
# ***************************************************************************
#  For Lasso()
# R2 score : 0.7073732683807448
# Mean absolute error:  167.84884312891637
# Mean squared error:  83323.9612950044
# Cross Validation Score= 0.4558979967905522
#
# ***************************************************************************
#  For SVR()
# R2 score : 0.40563729531924597
# Mean absolute error:  197.37252776026548
# Mean squared error:  169241.7323802501
# Cross Validation Score= 0.39406472322360403
#
# ...

# %% [markdown]
# From above results we see that r2 score for gradient boosting and random forest is the maximum but as per the cross val score gradient boosting performs better so we will be using the gradient boosting classifier

# %% [markdown]
# ## Hyperparameter Tuning

# %%
from sklearn.model_selection import GridSearchCV
param = {'n_estimators': [50, 100, 200],
    'learning_rate': [0.01, 0.1, 0.2],
    'max_depth': [3, 5, 7],
    'min_samples_split': [2, 5, 10],
    'min_samples_leaf': [1, 2, 4]}
gcs=GridSearchCV(GradientBoostingRegressor(),param,cv=5,n_jobs=-1)
gcs.fit(x_train,y_train)
gcs.best_params_
# Out:
# {'learning_rate': 0.1,
#  'max_depth': 7,
#  'min_samples_leaf': 4,
#  'min_samples_split': 10,
#  'n_estimators': 50}

# %%
fmodel_reg=GradientBoostingRegressor(n_estimators=50,learning_rate=0.1,min_samples_leaf= 4,
min_samples_split= 10,max_depth=10)
fmodel_reg.fit(x_train,y_train)
pred2=fmodel_reg.predict(x_test)
acc=r2_score(y_test,pred2)
print(acc*100)
# Out:
# 87.21554388231398

# %% [markdown]
# ## Plotting the best fit line according to our model

# %%
pt.scatter(x=y_test,y=mpred,color='palegreen')
pt.plot(y_test,y_test,color='saddlebrown')
pt.title('Best Fit Line',fontsize=18)
# Out:
# Text(0.5, 1.0, 'Best Fit Line')

# %% [markdown]
# ## Saving the model

# %%
joblib.dump(fmodel_reg,'Zomato_Avg-cost-for2.obj')
# Out:
# ['Zomato_Avg-cost-for2.obj']
